# %% [markdown]
# <a href="https://colab.research.google.com/github/dikshanaa-m/Fake-Profile-Generator/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install faker
from faker import Faker
fake = Faker()

for _ in range(5):
    print(f"Name: {fake.name()}, City: {fake.city()}")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 12.1 MB/s eta 0:00:00
# ...
# Name: Taylor Little, City: North Stephen
# Name: Alexa Moore, City: Sullivanstad
# Name: Gregory Padilla, City: Millerton
# Name: Brittany Short, City: Priscillatown
# Name: Mary Rodriguez, City: Romeroview
